# %% [markdown]
# # Сравнение моделей
#
# * Мешок слов и tf-idf
# * Word2Vec (fasttext, glove и тд)

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_score

import torch
import transformers as ppb

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Загрузка датасета

# %% [markdown]
# Для начала загрузите csv датасет

# %%
# Your code here

# %% [markdown]
# Посмотрите на классы. Они сбалансированы? Можно ли с ними работать? Также проверьте есть ли пропуски:

# %%
# Your code here

# %% [markdown]
# ## Мешок слов (CountVectorizer)

# %% [markdown]
# С помощью мешка слов постройте эмбеддинги для всех предложений и проведите классификацию с помощью:
#
# Логистической регрессии
#
# KNN
#
# Random forest
#
# Также выведите метрики: Accuracy, F1, ROC-AUC
#
# При этом поделите треин итест в пропорции 75:25

# %%
# Your code here

# %% [markdown]
# ## Tf-Idf

# %% [markdown]
# А теперь все то же самое, но с TF-IDF

# %%
# Your code here

# %% [markdown]
# ## N-grams

# %% [markdown]
# ![ngrams-2.png](data:image/png;base64,...)

# %% [markdown]
# Давайте попробуем побаловаться с n-gramками. Попробуйте в TF-IDF взять интервал n-gramок от 1 до 3

# %%
# Your code here

# %% [markdown]
# ## Word2Vec
#
# Большинство известных векторизаторов можно использовать в нескольких форматах:
# * обучать векторы с нуля на своих данных
# * дообучать модель (уже обученную) на своих данных
# * использовать предобученную модель

# %% [markdown]
# Попробуем с Word2Vec, вдург в этот раз он хорошо сработает. Можете взять код с ноутбука, который мы проходили на семинаре и используя код оттуда написать векторизатор word2vec для нашего датасета. Также примените все функции-клаффикаторы с предыдущих заданий (Логистическая регрессия, KNN, Random Forest)
#
# Не забудьте также посчитать метрики!

# %%
# Your code here

# %% [markdown]
# ## Предобученные модели из gensim

# %% [markdown]
# Можно загрузить векторы слов из предобученных моделей. Покажем, как это делать.

# %%
import gensim.downloader

print(list(gensim.downloader.info()['models'].keys()))
# Out:
# ['fasttext-wiki-news-subwords-300', 'conceptnet-numberbatch-17-06-300', 'word2vec-ruscorpora-300', 'word2vec-google-news-300', 'glove-wiki-gigaword-50', 'glove-wiki-gigaword-100', 'glove-wiki-gigaword-200', 'glove-wiki-gigaword-300', 'glove-twitter-25', 'glove-twitter-50', 'glove-twitter-100', 'glove-twitter-200', '__testing_word2vec-matrix-synopsis']

# %%
glove_vectors = gensim.downloader.load('glove-twitter-25')
# Out:
# [==================================================] 100.0% 104.8/104.8MB downloaded

# %%
glove_vectors['good']
# Out:
# array([-0.54403 ,  0.60274 , -0.14543 , -0.023398, -0.13771 ,  0.60137 ,
#         2.192   ,  0.20804 , -0.51536 , -0.23101 , -0.80387 ,  0.56901 ,
#        -5.0234  ,  0.26507 ,  0.47891 , -0.59854 ,  0.56132 , -1.0905  ,
#        -0.52587 ,  0.12506 , -0.22624 ,  0.24529 , -0.45767 ,  0.92619 ,
#         0.022125], dtype=float32)

# %% [markdown]
# И попробуйте теперь подобрать векторы из предобученных моделей для нашего датасета. Получилось? Посчитайте метрики
